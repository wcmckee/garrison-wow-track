# %% [markdown]
# Hearthstone Test

# %%
import requests
import bs4
import os
import json

# %%
reqjson = requests.get('http://hearthstonejson.com/json/AllSets.json')

# %%
dumjs = json.loads(reqjson.text)

# %%
basl = len(dumjs['Basic'])

# %%
for basl in range(0, basl):
    print(dumjs['Basic'][basl]['name'])
# Out:
# AFK
# Acidic Swamp Ooze
# Ancestral Healing
# Ancestral Infusion
# Anduin Wrynn
# Animal Companion
# Arcane Explosion
# Arcane Intellect
# Arcane Missiles
# Arcane Shot
# Arcanite Reaper
# Archmage
# Armor Up!
# Assassin's Blade
# Assassinate
# Avatar of the Coin
# Backstab
# Berserking
# Blessing of Kings
# Blessing of Kings
# Blessing of Might
# Blessing of Might
# Bloodfen Raptor
# Bloodlust
# Bloodlust
# Bluegill Warrior
# Boar
# Booty Bay Bodyguard
# Boulderfist Ogre
# Charge
# Charge
# Charge
# Charge
# Chillwind Yeti
# Claw
# Claw
# Claws
# Cleave
# Cleric's Blessing
# Coin's Vengeance
# Coin's Vengence
# Consecration
# Core Hound
# Corruption
# Corruption
# Dagger Mastery
# Dalaran Mage
# Darkscale Healer
# Deadly Poison
# Deadly Poison
# Divine Spirit
# Divine Spirit
# Dragonling Mechanic
# Drain Life
# Dread Infernal
# Elven Archer
# Enhanced
# Excess Mana
# Execute
# Eye In The Sky
# Fan of Knives
# Fiery War Axe
# Fire Elemental
# Fireball
# Fireblast
# Flamestrike
# ...
